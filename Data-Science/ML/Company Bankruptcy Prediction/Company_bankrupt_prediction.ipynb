# %% [markdown]
# <a href="">
#     <img src="https://cdn-images-1.medium.com/max/1200/1*u16a0WbJeckSdi6kGD3gVA.jpeg" width = 400>
# </a>
# <h1 align="center"><font size=5 color="DE5538">Breast Cancer</font></h1>

# %% [markdown]
# # Company Bankruptcy Prediction
# [Download kaggle Data Set here](https://www.kaggle.com/fedesoriano/company-bankruptcy-prediction)
#
# #### Context
# The data were collected from the Taiwan Economic Journal for the years 1999 to 2009. Company bankruptcy was defined based on the business regulations of the Taiwan Stock Exchange.
#
# #### Attribute Information
# <li>X0 Class label</li>
# <li>X1 Cost of Interest-bearing Debt</li>
# <li>X2 Cash Reinvestment Ratio</li>
# <li>X3 Current Ratio</li>
# <li>X4 Acid Test</li>
# <li>X5 Interest Expenses/Total Revenue</li>
# <li>X6 Total Liability/Equity Ratio</li>
# <li>X7 Liability/Total Assets</li>
# <li>X8 Interest-bearing Debt/Equity</li>
# <li>X9 Contingent Liability/Equity</li>
# <li>X10 Operating Income/Capital</li>
# <li>X11 Pretax Income/Capital</li>
# <li>X12 Working Capital to Total Assets</li>
# <li>X13 Quick Assets/Total assets</li>
# <li>X14 Current Assets/Total Assets</li>
# <li>X15 Cash/Total Assets</li>
# <li>X16 Quick Assets/Current Liability</li>
# <li>X17 Cash/Current Liability</li>
# <li>X18 Current Liability to Assets</li>
# <li>X19 Operating Funds to Liability</li>
# <li>X20 Inventory/Working Capital</li>
# <li>X21 Inventory/Current Liability</li>
# <li>X22 Current Liabilities/Liability</li>
# <li>X23 Working Capital/Equity</li>
# <li>X24 Current Liabilities/Equity</li>
# <li>X25 Long-term Liability to Current Assets</li>
# <li>X26 Current Liability to Current Assets</li>
# <li>X27 One if Total Liability exceeds Total Assets;</li>
# <li>X28 Equity to Liability</li>
# <li>X29 Equity/Total Assets</li>
# <li>X30 (Long-term Liability+Equity)/Fixed Assets</li>
# <li>X31 Fixed Assets to Assets</li>
# <li>X32 Current Liability to Liability</li>
# <li>X33 Current Liability to Equity</li>
# <li>X34 Equity to Long-term Liability</li>
# <li>X35 Liability to Equity</li>
# <li>X36 Degree of Financial Leverage</li>
# <li>X37 Interest Coverage Ratio</li>
# <li>X38 Operating Expenses/Net Sales</li>
# <li>X39 (Research and Development Expenses)/Net Sales</li>
# <li>X40 Effective Tax Rate</li>
# <li>X41 Book Value Per Share(B)</li>
# <li>X42 Book Value Per Share(A)</li>
# <li>X43 Book Value Per Share(C)</li>
# <li>X44 Cash Flow Per Share</li>
# <li>X45 Sales Per Share</li>
# <li>X46 Operating Income Per Share</li>
# <li>X47 Sales Per Employee</li>
# <li>X48 Operation Income Per Employee</li>
# <li>X49 Fixed Assets Per Employee</li>
# <li>X50 total assets to GNP price</li>
# <li>X51 Return On Total Assets(C)</li>
# <li>X52 Return On Total Assets(A)</li>
# <li>X53 Return On Total Assets(B)</li>
# <li>X54 Gross Profit /Net Sales</li>
# <li>X55 Realized Gross Profit/Net Sales</li>
# <li>X56 Operating Income /Net Sales</li>
# <li>X57 Pre-Tax Income/Net Sales</li>
# <li>X58 Net Income/Net Sales</li>
# <li>X59 Net Non-operating Income Ratio</li>
# <li>X60 Net Income-Exclude Disposal Gain or Loss/Net Sales</li>
# <li>X61 EPS-Net Income</li>
# <li>X62 Pretax Income Per Share</li>
# <li>X63 Retained Earnings to Total Assets</li>
# <li>X64 Total Income to Total Expenses</li>
# <li>X65 Total Expenses to Assets</li>
# <li>X66 Net Income to Total Assets</li>
# <li>X67 Gross Profit to Sales</li>
# <li>X68 Net Income to Stockholder's Equity</li>
# <li>X69 One if Net Income is Negative for the Last Two Years; Zero Otherwise</li>
# <li>X70 (Inventory +Accounts Receivables) /Equity</li>
# <li>X71 Total Asset Turnover</li>
# <li>X72 Accounts Receivable Turnover</li>
# <li>X73 Days Receivable Outstanding</li>
# <li>X74 Inventory Turnover</li>
# <li>X75 Fixed Asset Turnover</li>
# <li>X76 Equity Turnover</li>
# <li>X77 Current Assets to Sales</li>
# <li>X78 Quick Assets to Sales</li>
# <li>X79 Working Capital to Sales</li>
# <li>X80 Cash to Sales</li>
# <li>X81 Cash Flow to Sales</li>
# <li>X82 No-credit Interval</li>
# <li>X83 Cash Flow from Operating/Current Liabilities</li>
# <li>X84 Cash Flow to Total Assets</li>
# <li>X85 Cash Flow to Liability</li>
# <li>X86 CFO to Assets</li>
# <li>X87 Cash Flow to Equity</li>
# <li>X88 Realized Gross Profit Growth Rate</li>
# <li>X89 Operating Income Growth</li>
# <li>X90 Net Income Growth</li>
# <li>X91 Continuing Operating Income after Tax Growth</li>
# <li>X92 Net Income-Excluding Disposal Gain or Loss Growth</li>
# <li>X93 Total Asset Growth</li>
# <li>X94 Total Equity Growth</li>
# <li>X95 Return on Total Asset Growth</li>
#
# #### Source
# Deron Liang and Chih-Fong Tsai, deronliang '@' gmail.com; cftsai '@' mgt.ncu.edu.tw, National Central University, Taiwan
# The data was obtained from UCI Machine Learning Repository: https://archive.ics.uci.edu/ml/datasets/Taiwanese+Bankruptcy+Prediction

# %% [markdown]
# ## Load data and explore

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Import Sklearn libraries
from sklearn.model_selection import GridSearchCV, train_test_split

# to make this notebook's output stable across runs
np.random.seed(2210)

# Set some options
pd.set_option("display.max_colwidth", 100)
sns.set_theme(style="whitegrid", palette="Set3")

# Set Matplotlib defaults
# %matplotlib inline
purple_color = "#b753e6"
_ = plt.tight_layout

# %%
df = pd.read_csv("data.csv.zip")
df.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                                  0.370594
# 1          1                                                  0.464291
# 2          1                                                  0.426071
# 3          1                                                  0.399844
# 4          1                                                  0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                            0.405750
# 1                                            0.516730
# 2                                            0.472295
# ...

# %%
dict = df['Bankrupt?'].value_counts().to_dict()
df['Bankrupt?'].map(dict).value_counts()
# Out:
# 6599    6599
# 220      220
# Name: Bankrupt?, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Bankrupt?                                                            6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest             6819 non-null   float64
#  2    ROA(A) before interest and % after tax                              6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax                   6819 non-null   float64
#  4    operating gross margin                                              6819 non-null   float64
#  5    realized sales gross margin                                         6819 non-null   float64
# ...

# %%
df.describe()
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                               6819.000000
# mean      0.032263                                                  0.505180
# std       0.176710                                                  0.060686
# min       0.000000                                                  0.000000
# 25%       0.000000                                                  0.476527
# 50%       0.000000                                                  0.502706
# 75%       0.000000                                                  0.535563
# max       1.000000                                                  1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# ...

# %%
print( f"No. of columns having null values in them {len(df.columns[df.isna().sum() > 0])}" )
# Out:
# No. of columns having null values in them 0

# %%
_ = df.hist(figsize=(40, 20), color=color)

# %% [markdown]
# ## Data Exploration

# %%
import sys
sys.path.append('/home/jovyan/mylib')

import helper, charts, ml

# %%
from sklearn.feature_selection import chi2


def get_data():
    df = pd.read_csv("data.csv.zip")
    # Convert columns to lower and remove spl characters
    import re

    df.columns = df.columns.map(
        lambda x: re.sub("[^a-zA-Z0-9_ \n\.]", "",
                         x.strip().lower().replace(" ", "_")))

    # Split into X and y
    X, y = df.drop("bankrupt", axis=1), df["bankrupt"]
    X = helper.drop_columns_by_variance(X, 0.1)

    return X, y


# Fetch the data
X, y = get_data()
# Choose only columns having higher Threshold
variance_cols = helper.get_columns_by_variance(X, y, 0.1)

from sklearn.feature_selection import chi2, mutual_info_classif

# Choose kbest_columns for chi and mutual_classification_info and best percentile
best_cols_chi = helper.get_kbest_columns(X, y, score_func=chi2, k=15)
best_cols_mu = helper.get_kbest_columns(X, y, score_func=mutual_info_classif, k=15)
best_percentile_cols = helper.get_percentile_columns(X, y, score_func=chi2, percentile=20)
# Out:
# Dropping columns : {'one_if_net_income_was_negative_for_the_last_two_year_zero_otherwise'}

# %% [markdown]
# There is a lot of skew in the data, we will be using Stratified Sampling for data split.
# Target columns are highly imbalanced and need to be picked up in stratified form
# Do not use Shuffling with KFolds

# %%
_= sns.countplot(x=y, palette='Set2')
print(y.value_counts())
# Out:
# 0    6599
# 1     220
# Name: bankrupt, dtype: int64

# %%
import charts
charts.plot_stripviolens(X, cols, figsize=(20, 20))

# %% [markdown]
# We can see there are many outliers present in the data

# %%
from sklearn.preprocessing import PowerTransformer

transformer = PowerTransformer().fit(X[cols])
X_ = transformer.transform(X[cols])
X_ = pd.DataFrame(data=X_, columns=cols)
charts.plot_stripviolens(X_, cols, figsize=(20, 20))

# %% [markdown]
# ### Choose only the best columns using SelectFromModel or RFECV

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.feature_selection import SelectFromModel
estimator=RandomForestClassifier()
selector = SelectFromModel(estimator).fit(X, y)
# see the selected features.
selected_features = X.columns[(selector.get_support())]
print(selected_features)
# pd.Series(selector.estimator_.feature_importances_, selected_features).sort_values(ascending=False)
# Out:
# Index(['roac_before_interest_and_depreciation_before_interest',
#        'roab_before_interest_and_depreciation_after_tax',
#        'nonindustry_income_and_expenditurerevenue',
#        'continuous_interest_rate_after_tax', 'operating_expense_rate',
#        'interestbearing_debt_interest_rate', 'per_net_share_value_b',
#        'net_value_per_share_a', 'net_value_per_share_c',
#        'persistent_eps_in_the_last_four_seasons',
#        'per_share_net_profit_before_tax_yuan', 'net_value_growth_rate',
#        'quick_ratio', 'interest_expense_ratio', 'total_debttotal_net_worth',
#        'debt_ratio_', 'net_worthassets', 'borrowing_dependency',
#        'net_profit_before_taxpaidin_capital', 'accounts_receivable_turnover',
#        'fixed_assets_turnover_frequency', 'working_capital_to_total_assets',
#        'cash__total_assets', 'cash__current_liability',
#        'inventoryworking_capital', 'working_capitalequity',
# ...

# %%
estimator=RandomForestClassifier()
cv = StratifiedKFold(n_splits=5, shuffle=False)
selector = RFECV(estimator, step=1, cv=cv, scoring='accuracy')
selector = selector.fit(X, y)


selected_columns = X.columns[selector.support_]
selector.estimator_.feature_importances_
pd.Series(selector.estimator_.feature_importances_, selected_columns).sort_values(ascending=False)

# %% [markdown]
# ## View performance of the model with All features and selected ones

# %%
cv = StratifiedKFold(n_splits=5, shuffle=False)
for train_index, test_index in cv.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    print(len(train_index), len(test_index))

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.2, stratify=y)
X_train.shape, X_test.shape
# Out:
# 5455 1364
# 5455 1364
# 5455 1364
# 5455 1364
# 5456 1363
# ((1363, 94), (5456, 94))

# %%
df_score, search_grid = ml.select_classifiers(
    X_train=X_train[selected_features],
    y_train=y_train,
    X_test=X_test[selected_features],
    y_test=y_test,
    is_binary=True, 
    cv=cv,
    sort_by = ['roc_auc', 'precision']
)

# %%
df_score
# Out:
#                     estimator  mean_val_score  std_val_score  mean_fit_time  \
# 1      RandomForestClassifier        0.972856       0.005943       0.410831
# 3                         SVM        0.967720       0.001435       0.013595
# 7               SGDClassifier        0.942741       0.035717       0.009313
# 5          LogisticRegression        0.966984       0.000059       0.042415
# 0               XGBClassifier        0.974319       0.008367       0.631585
# 2  GradinetBoostingClassifier        0.968460       0.013008       0.928756
# 4          AdaBoostClassifier        0.966984       0.012703       0.289665
# 6      DecisionTreeClassifier        0.954514       0.014388       0.034091
#
#    mean_score_time params_x params_y  accuracy  precision    recall  f1-score  \
# 1         0.014400       {}       {}  0.968109   0.519231  0.153409  0.236842
# 3         0.005252       {}       {}  0.967742   0.000000  0.000000  0.000000
# ...

# %% [markdown]
# ### Fine tune the models

# %%
np.arange(0.01, 1, 0.05)
# Out:
# array([0.01, 0.06, 0.11, 0.16, 0.21, 0.26, 0.31, 0.36, 0.41, 0.46, 0.51,
#        0.56, 0.61, 0.66, 0.71, 0.76, 0.81, 0.86, 0.91, 0.96])

# %%
models = {
    'RandomForestClassifier': (RandomForestClassifier(), {
        'n_estimators': range(20, 101, 5),
        'max_depth': range(4, 14, 2),
        'bootstrap': [True, False],
        'min_samples_leaf': range(80, 400, 40),
    }),
#     'AdaBoostClassifier': (AdaBoostClassifier(), {
#         'n_estimators': range(20, 100, 5),
#         'learning_rate': [0.01, 0.05, 0.1, 0.3, 0.5, 1]
#     }),
#     'GradinetBoostingClassifier':
#         (GradientBoostingClassifier(DecisionTreeClassifier()), {
#             'n_estimators': range(20, 100, 5),
#             'learning_rate': [0.01, 0.05, 0.1, 0.3, 0.5, 1]
#         }),
    #         'XGBClassifier': (XGBClassifier(verbose=0), {}),
}

select = ml.ClassifierSelectHelper(models)
select.fit(X_train, y_train, cv=cv, verbose=0)
df_score, search_grid = select.score_summary(X_test, y_test, sort_by=['precision', 'recall'])

# search_grid
for key, grid in search_grid.items():
    print(grid.best_estimator_)
# Out:
# Running GridSearchCV for RandomForestClassifier
# RandomForestClassifier(max_depth=4, min_samples_leaf=80, n_estimators=20)
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
df_score
# Out:
#                    estimator  mean_val_score  std_val_score  mean_fit_time  \
# 0     RandomForestClassifier         0.96772       0.001435       0.093986
# 1     RandomForestClassifier         0.96772       0.001435       0.130520
# 2     RandomForestClassifier         0.96772       0.001435       0.235773
# 3     RandomForestClassifier         0.96772       0.001435       0.221871
# 4     RandomForestClassifier         0.96772       0.001435       0.208705
# ...                      ...             ...            ...            ...
# 1355  RandomForestClassifier         0.96772       0.001435       0.252857
# 1356  RandomForestClassifier         0.96772       0.001435       0.200305
# 1357  RandomForestClassifier         0.96772       0.001435       0.175313
# 1358  RandomForestClassifier         0.96772       0.001435       0.155656
# 1359  RandomForestClassifier         0.96772       0.001435       0.271277
#
#       mean_score_time  \
# 0            0.006283
# ...
